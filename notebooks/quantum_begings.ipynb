# %% [markdown]
# # Do the "Hello Worl" example on a 2-qubit Bell state

# %% [markdown]
# ## Step 1: Map the problem to circuits and operators

# %%
from qiskit import QuantumCircuit

qc = QuantumCircuit(2)

qc.h(0)
qc.cx(0, 1)

qc.draw(output="mpl")
