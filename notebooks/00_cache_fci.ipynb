# %%
from src.data.cache import cache_fci

# %% [markdown]
# # $H_2$

# %%
def h2_geom(d):
    return f"H 0 0 0; H 0 0 {d}"

cache_fci("H2", geometry_fn=h2_geom)

# %% [markdown]
# # $LiH$

# %%
def lih_geom(d):
    return f"Li 0 0 0; H 0 0 {d}"

for basis in ["sto-3g", "6-31g", "cc-pvdz"]:
    cache_fci("LiH", geometry_fn=lih_geom, basis=basis)

# %% [markdown]
# # $Li_2O$ (simplified linear)

# %%
# def li2o_geom(d):
#     return f"Li 0 0 {-d}; O 0 0 0; Li 0 0 {d}"
# 
# for basis in ["sto-3g", "6-31g"]
#     cache_fci("Li2O", geometry_fn=li2o_geom, basis=basis)
