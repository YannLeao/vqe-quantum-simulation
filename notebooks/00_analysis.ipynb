# %% [markdown]
# ## Análise de convergência
#
# Este notebook apresenta os gráficos de convergência do algoritmo
# Variational Quantum Eigensolver (VQE) para os sistemas moleculares
# simulados.
#
# Os dados de otimização previamente armazenados são carregados e
# utilizados para visualizar a evolução da energia ao longo das
# iterações variacionais, permitindo avaliar o comportamento de
# convergência do método.

# %%
from src.utils import plot_vqe_convergence

# H2
plot_vqe_convergence(
    "data/results/h2_history.csv",
    "VQE Convergence - Hydrogen Molecule (H₂)",
    "h2_convergence.png",
)

# %%
# LiH
plot_vqe_convergence(
    "data/results/lih_history.csv",
    "VQE Convergence - Lithium Hydride (LiH)",
    "lih_convergence.png",
)

# %%
# Li20
# plot_vqe_convergence(
#     "data/results/li2o_history.csv",
#     "VQE Convergence - Lithium Oxide (Li2O)",
#     "lih_convergence.png",
# )
