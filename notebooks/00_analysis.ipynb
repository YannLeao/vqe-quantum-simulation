# %%
from pyscf.mcscf import addons

print(dir(addons))
# Out:
# ['RANGE_TYPE', 'StateAverageFCISolver', 'StateAverageMCSCF', 'StateAverageMCSCFSolver', 'StateAverageMixFCISolver', 'StateAverageMixFCISolver_solver_args', 'StateAverageMixFCISolver_state_args', 'StateSpecificFCISolver', '__builtins__', '__cached__', '__config__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_is_uhf_mo', '_make_rdm12_on_mo', '_state_average_mcscf_solver', 'cas_natorb', 'caslst_by_irrep', 'fci', 'get_fock', 'get_spin_square', 'gto', 'lib', 'logger', 'make_natural_orbitals', 'make_rdm1', 'make_rdm12', 'make_rdm1s', 'make_spin_casdm1', 'map2hf', 'numpy', 'project_init_guess', 'project_init_guess_old', 'reduce', 'scf', 'scipy', 'select_mo_by_irrep', 'sort_mo', 'sort_mo_by_irrep', 'spin_square', 'state_average', 'state_average_', 'state_average_mix', 'state_average_mix_', 'state_specific', 'state_specific_', 'symm', 'sys']
